# %% [markdown]
# <a href="https://colab.research.google.com/github/fzanartu/github-slideshow/blob/master/autosklearnmodel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt-get install build-essential swig
# !pip install auto-sklearn==0.11.1
# !pip install dask distributed --upgrade
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# build-essential is already the newest version (12.4ubuntu1).
# swig is already the newest version (3.0.12-1).
# 0 upgraded, 0 newly installed, 0 to remove and 31 not upgraded.
# ...
# Requirement already up-to-date: dask in /usr/local/lib/python3.7/dist-packages (2021.4.0)
# Requirement already up-to-date: distributed in /usr/local/lib/python3.7/dist-packages (2021.4.0)
# ...

# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd 
X_train = pd.read_csv('/content/X_train.csv', index_col=0)
X_test = pd.read_csv('/content/X_test.csv', index_col=0)
y_train = pd.read_csv('/content/y_train.csv', index_col=0)
y_test = pd.read_csv('/content/y_test.csv', index_col=0)

# %%
X_train
# Out:
#       d: accept  d: accord  d: action  ...  Releases Count  Stars  Forks
# 927           1          0          0  ...             0.0   5570   2559
# 537           0          0          0  ...            68.0   7584   1070
# 2837          0          0          0  ...            16.0   2579    973
# 4659          0          0          0  ...             1.0   1743    180
# 3833          0          0          0  ...             3.0   2039    486
# ...         ...        ...        ...  ...             ...    ...    ...
# 3751          0          0          0  ...           668.0   2074    220
# 3343          0          0          0  ...             0.0   2278    653
# 999           0          0          0  ...             0.0   5300    164
# 1373          0          0          0  ...             0.0   4276    380
# 4282          0          0          0  ...            17.0   1864    334
#
# [2983 rows x 36030 columns]

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
#y_test = y_test.apply(le.fit_transform)
y_train = pd.read_csv('/content/y_train.csv', index_col=0)
y_train = y_train.apply(le.fit_transform)

# %%
import numpy as np

y_train = y_train.to_numpy()
#y_test = y_test.to_numpy()
np.count_nonzero(np.isnan(y_train))
# Out:
# 0

# %%
a_sum
# Out:
# 8740

# %%
import autosklearn.classification
from sklearn.utils.multiclass import type_of_target
automl = autosklearn.classification.AutoSklearnClassifier(
    time_left_for_this_task=60,
    per_run_time_limit=30,
    initial_configurations_via_metalearning=0,
    smac_scenario_args={'runcount_limit': 1},
)
automl.fit(
  X_train,
  y_train
)
# Out:
# /usr/local/lib/python3.7/dist-packages/pyparsing.py:3190: FutureWarning: Possible set intersection at position 3
#   self.re = re.compile(self.reString)
# /usr/local/lib/python3.7/dist-packages/autosklearn/automl.py:1197: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Will change shape via np.ravel().
#   self.InputValidator.validate_target(input_y, is_classification=True)
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-913a9df93f0b> in <module>()
#       9 automl.fit(
#      10   X_train,
# ---> 11   y_train
#      12 )
#
# /usr/local/lib/python3.7/dist-packages/autosklearn/estimators.py in fit(self, X, y, X_test, y_test, feat_type, dataset_name)
#     587             y_test=y_test,
#     588             feat_type=feat_type,
# ...
